# %%
import os

# 폴더 생성
os.makedirs('./new_folder', exist_ok=True)

# %%
# %%writefile ./new_folder/mymath1.py
# mymath.py 파일 생성 및 함수 정의

def add(x, y):
    return x + y

def multiply(x, y):
    return x * y

def subtract(x, y):
    return x - y
# Out:
# Writing ./new_folder/mymath1.py

# %%
import sys
# 모듈이 위치한 폴더의 경로를 sys.path에 추가
sys.path.append('./new_folder')

import mymath1  # mymath 모듈 불러오기

# 함수 사용 예시
a = 10
b = 5

# 덧셈
print("Addition:", mymath.add(a, b))

# 곱셈
print("Multiplication:", mymath.multiply(a, b))

# 뺄셈
print("Subtraction:", mymath.subtract(a, b))
# Out:
# Addition: 15
# Multiplication: 50
# Subtraction: 5

# %%
import mymath  # mymath 모듈 불러오기

# 함수 사용 예시
a = 10
b = 5

# 덧셈
print("Addition:", mymath.add(a, b))

# 곱셈
print("Multiplication:", mymath.multiply(a, b))

# 뺄셈
print("Subtraction:", mymath.subtract(a, b))
# Out:
# Addition: 15
# Multiplication: 50
# Subtraction: 5
