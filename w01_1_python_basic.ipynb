# %% [markdown]
# # **파이썬프로그래밍-2** : Python Basic
# # <font color='red'>출석 인증번호 : **481**

# %% [markdown]
# ## 기본 변수(Variable, 變數) 타입
# ### Numeric, Boolean, String 타입에 대해 알아보고 관련 연산자 및 함수들을 테스트해봅니다.
# ---

# %% [markdown]
# ### 1. Numeric(수치형 변수)
# #### 가장 기본이 되는 숫자 관련 변수와 기본적인 연산에 대해 배워보도록 하겠습니다.
#
# ---

# %%
x = 3
y = 3
z = 5

# %%
print(x, y, z)
# Out:
# 3 3 5

# %%
print(id(x))
print(id(y))
print(id(z))
# Out:
# 140018928910640
# 140018928910640
# 140018928910704

# %% [markdown]
# <img src= 'https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F263C1D4052183DFB25'>

# %%
# 3이라는 정수는 메모리 고유값이 있다(절대주소)
print(id(3))
print(id(5))
# Out:
# 140018928910640
# 140018928910704

# %%
# 정수형 변수 선언
x = 1
print(x)
print(type(x))
# Out:
# 1
# <class 'int'>

# %% [markdown]
# <img src='https://cpbc.co.kr/CMS/newspaper/2004/05/rc/165128_1.0_titleImage_1.jpg'>
#
# <img src='https://dr282zn36sxxg.cloudfront.net/datastreams/f-d%3Ab9062d6710ed2318d6ea7dba489d5ce33e808c6a05d777fbb1d4c6f9%2BIMAGE_TINY%2BIMAGE_TINY.1'>

# %%
# 유리수형 변수 선언
x = 1.0
print(x)
print(type(x))
# Out:
# 1.0
# <class 'float'>

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
id(x), type(x)
# Out:
# (140059983695952, float)

# %%
# 사칙연산을 계산해봅니다.
x = 9
print(x+3)
print(x-3)
print(x*3)
print(x/3) # 옵션 1
# Out:
# 12
# 6
# 27
# 3.0

# %%
# CPU와 메모리
x = 120
y = 100
print(id(x))
print(id(y))
x + y
# Out:
# 140018928914384
# 140018928913744
# 220

# %%
z = x + y
print(id(z))               # 140018928914384 번지와 140018928913744번지에 있는 수치를 더해서 z번지에 저장하라
print(z)
# Out:
# 140018928917584
# 220

# %% [markdown]
# <img src= 'https://hongong.hanbit.co.kr/wp-content/uploads/2022/09/%EB%A9%94%EB%AA%A8%EB%A6%AC-%EC%93%B0%EA%B8%B0-%EC%A0%9C%EC%96%B4-%EC%8B%A0%ED%98%B8.png'>
#
# # 컴퓨터의 구조
# <img src='https://hongong.hanbit.co.kr/wp-content/uploads/2022/09/%EC%BB%B4%ED%93%A8%ED%84%B0%EC%9D%98-%EA%B5%AC%EC%A1%B0.png' width = 800 height=500>

# %%
# 거듭제곱, 몫, 나머지
x = 9
print(x**4)
print(x//4)
print(x%4)
# Out:
# 6561
# 2
# 1

# %%
b= 3

# %%
# 기존변수에 추가적인 연산
a = 3
a = a +1
print(a)
a += 1           # a = a +1과 동일한 산술식
print(a)
# Out:
# 4
# 5

# %%
# 변수 교환
a = 4
b = 10
# Out:
# 4 10

# %%
temp = a
a = b
b = temp    # temp를 사용 안하면 어떻게 될까?
print(a,b)
# Out:
# 10 4
# 4 10

# %%
a, b = b, a
print(a,b)
# Out:
# 4 10

# %%
# 비교연산
a = 3
b = 5
print(a > b)
print(a < b)
print(a <= b)
print(a >= b)
print(a == b)
print(a != b)
print(a is b)
print(a is not b)
# Out:
# False
# True
# True
# False
# False
# True
# False
# True

# %%
# Q. 1.0 + 3의 타입은 int? float?

# %%
# Q. Int를 Float으로

# %%
a = 1.0

# %%
# Q. Float을 Int로

# %%
# Q. 제곱근은 어떻게 구할까?

# %% [markdown]
# ### 2. Boolean
# #### 부울 (bool) 변수와 논리 연산자에 대해 알아보도록 하겠습니다.
# ---

# %%
# 변수선언
x = True
print(x)
print(type(x))
# Out:
# True
# <class 'bool'>

# %%
# 논리 연산자 option #1: &, |
print(True & False)
print(True | False)
# Out:
# False
# True

# %%
# 논리 연산자 option #2: AND, OR
print(True and False)
print(True or False)
# Out:
# False
# True

# %%
#Q. True + 1 = ?

# %%
#Q. False * 3 = ?

# %%
#Q. True + True = ?

# %% [markdown]
# ### 3. String (중요!), 데이터 wrangle에 핵심
# #### 텍스트 마이닝에서 가장 중요한 문자열 변수와 이에 필요한 관련 함수들에 대해 알아보겠습니다.
# ---

# %%
# 변수 선언
x = 'bac, 2 3 5 56 $^&^난'
print(x)
print(type(x))
# Out:
# abc, 2 3 5 56 $^&^난
# <class 'str'>

# %%
x[4]
# Out:
# ' '

# %%
# 문자열 비교
print('abc' == 'ABC')
print('abc' == 'abc')
# Out:
# False
# True

# %%
# 문자열 결합 연산
'abc'+'ABC'
# Out:
# 'abcABC'

# %%
# Q. 다른 수학 연산자들은?

# %% [markdown]
# #### 유용한 문자열 관련 함수 들
# ___

# %%
x ="hello, this is python programing course 2"

# %%
# 문자열 길이계산
len(x)
# Out:
# 41

# %%
# 문자 치환
x.replace("h","x")
# Out:
# 'xello, txis is pytxon programing course 2'

# %%
# 단어 치환
x.replace("hello","Hi")
# Out:
# 'Hi, this is python programing course 2'

# %%
# 문자/단어 존재여부 검사
"this" in x
# Out:
# True

# %%
# 문자/단어 위치 확인 (가장 먼저 발견된)
print(x.index("this"))    # 'this'라는 단어는 7번째 text에서 등장, 'that'은 ?
print(x.find('i'))
# Out:
# 7
# 9

# %%
x
# Out:
# 'hello, this is python programing course 2'

# %%
# find와 index의 차이
print(x.find("thiss"))
print(x.index("thiss"))
# Out:
# -1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-8c1812b7b058> in <cell line: 3>()
#       1 # find와 index의 차이
#       2 print(x.find("thiss"))
# ----> 3 print(x.index("thiss"))
#
# ValueError: substring not found

# %%
# Q.없는 단어의 index 값은?

# %% [markdown]
# - find() returns -1 if the substring is not found.
# - index() raises a ValueError exception if the substring is not found.

# %%
# 문자/단어 위치 확인 (좌부터/우부터)
print(x.find("e"))
print(x.rfind("e"))
# Out:
# 1
# 38

# %% [markdown]
# #### 단어 대소문자 관련 함수들 (영문만 해당)
# ___

# %%
x
# Out:
# 'hello, this is python programing course 2'

# %%
x.upper()
# Out:
# 'HELLO, THIS IS PYTHON PROGRAMING COURSE 2'

# %%
x.lower()
# Out:
# 'hello, this is python programing course 2'

# %%
x.capitalize()
# Out:
# 'Hello, this is python programing course 2'

# %%
x.title()
# Out:
# 'Hello, This Is Python Programing Course 2'

# %% [markdown]
# ## 기타

# %%
# 이것은 한줄짜리 주석입니다

"""
이것은
여러줄을
한번에 주석
처리하는 방식입니다.
"""
print("이것은 출력입니다")
# Out:
# 이것은 출력입니다

# %%
#print 하는 방법
name = "홍길동"
major = "빅데이터"
weight = 68.5334

print("안녕하세요, 저의 이름은 "+name+"이고"+" 전공은 "+major+"이고"+" 몸무게는 "+str(round(weight,2))+"kg 입니다.")
print("안녕하세요, 저의 이름은 %s이고 전공은 %s이고 몸무게는 %.2fkg 입니다." % (name, major, weight))
print("안녕하세요, 저의 이름은 {}이고 전공은 {}이고 몸무게는 {:.2f}kg 입니다.".format(name,major,weight))
print(f"안녕하세요, 저의 이름은 {name}이고 전공은 {major}이고 몸무게는 {weight:.2f}kg 입니다.")
# Out:
# 안녕하세요, 저의 이름은 홍길동이고 전공은 빅데이터이고 몸무게는 68.53kg 입니다.
# 안녕하세요, 저의 이름은 홍길동이고 전공은 빅데이터이고 몸무게는 68.53kg 입니다.
# 안녕하세요, 저의 이름은 홍길동이고 전공은 빅데이터이고 몸무게는 68.53kg 입니다.
# 안녕하세요, 저의 이름은 홍길동이고 전공은 빅데이터이고 몸무게는 68.53kg 입니다.

# %%
# f string 처리 방법
print(f"안녕하세요, 저의 이름은 {name}이고 전공은 {major} 이고 몸무게는 {weight} kg 입니다.")
# Out:
# 안녕하세요, 저의 이름은 홍길동이고 전공은 빅데이터 이고 몸무게는 68.5334 kg 입니다.

# %%
print(f"안녕하세요, 저의 이름은 {name}이고 전공은 {major} 이고 몸무게는 {weight:.2f} kg 입니다.")
# Out:
# 안녕하세요, 저의 이름은 홍길동이고 전공은 빅데이터 이고 몸무게는 68.53 kg 입니다.
