# %%
BOOKS = [
    {'title': 'Title One', 'author': 'Author One', 'category': 'science'},
    {'title': 'Title Two', 'author': 'Author Two', 'category': 'science'},
    {'title': 'Title Three', 'author': 'Author Three', 'category': 'history'},
    {'title': 'Title Four', 'author': 'Author Four', 'category': 'math'},
    {'title': 'Title Five', 'author': 'Author Five', 'category': 'math'},
    {'title': 'Title Six', 'author': 'Author Two', 'category': 'math'}
]

# %%
def deco(fn):
    print("*" * 20)    # 기능 추가
    fn()               # 기존 함수 호출
    print("*" * 20)    # 기능 추가

    return fn()

# %%
def read_all_books():
    print('Return BOOKS')
    return BOOKS

# %%
read_all_books()
# Out:
# Return BOOKS
# [{'title': 'Title One', 'author': 'Author One', 'category': 'science'},
#  {'title': 'Title Two', 'author': 'Author Two', 'category': 'science'},
#  {'title': 'Title Three', 'author': 'Author Three', 'category': 'history'},
#  {'title': 'Title Four', 'author': 'Author Four', 'category': 'math'},
#  {'title': 'Title Five', 'author': 'Author Five', 'category': 'math'},
#  {'title': 'Title Six', 'author': 'Author Two', 'category': 'math'}]

# %%
read = deco(read_all_books)
get_read = read()
# Out:
# ********************
# Return BOOKS
# ********************
# Return BOOKS
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-208119c54fef> in <cell line: 2>()
#       1 read = deco(read_all_books)
# ----> 2 get_read = read()
#
# TypeError: 'list' object is not callable

# %%
BOOKS
# Out:
# [{'title': 'Title One', 'author': 'Author One', 'category': 'science'},
#  {'title': 'Title Two', 'author': 'Author Two', 'category': 'science'},
#  {'title': 'Title Three', 'author': 'Author Three', 'category': 'history'},
#  {'title': 'Title Four', 'author': 'Author Four', 'category': 'math'},
#  {'title': 'Title Five', 'author': 'Author Five', 'category': 'math'},
#  {'title': 'Title Six', 'author': 'Author Two', 'category': 'math'}]

# %%
 book = BOOKS[0]
 book
# Out:
# {'title': 'Title One', 'author': 'Author One', 'category': 'science'}

# %%
book.get('title')
# Out:
# 'Title One'

# %%
str1 = "HellO"
str2 = "hello"

if str1.casefold() == str2.casefold():
    print("Strings are case-insensitive equal")
else:
    print("Strings are not case-insensitive equal")
# Out:
# Strings are case-insensitive equal

# %%
for book in BOOKS:
    print(book)
# Out:
# {'title': 'Title One', 'author': 'Author One', 'category': 'science'}
# {'title': 'Title Two', 'author': 'Author Two', 'category': 'science'}
# {'title': 'Title Three', 'author': 'Author Three', 'category': 'history'}
# {'title': 'Title Four', 'author': 'Author Four', 'category': 'math'}
# {'title': 'Title Five', 'author': 'Author Five', 'category': 'math'}
# {'title': 'Title Six', 'author': 'Author Two', 'category': 'math'}
